# %%
import pandas as pd
df = pd.read_csv('ai_vs_human_text_detection_dataset.csv')
df = df[df["language"] == "en"]

# %%
df.head()
# Out:
#                                       id  \
# 2   b5e06ef0-9758-471f-81dc-182c6117ee81
# 3   6177fc40-1567-445b-af15-f3250ddd3403
# 5   6dd66380-1925-42a8-9efa-bfb89dc88637
# 14  7bdfb87a-59a4-43ab-80f5-745d7222cb64
# 17  9ff8234d-c904-483f-ba9f-b8926e16925f
#
#                                                  text human_or_ai  \
# 2   Error: 404 Client Error: Not Found for url: ht...          ai
# 3   **Global Economic Trends: A Shifting Landscape...          ai
# 5   Hi Sarah\n\nThank you for taking the time to i...       human
# 14  machine learning is becoming really popular th...       human
# 17  Photosynthesis is how plants make food using s...       human
#
#                            source_model  \
# 2   gemma2-9b-itllama-3.3-70b-versatile
# 3                  llama-3.1-8b-instant
# 5                                 Human
# 14                                Human
# 17                                Human
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 246 entries, 2 to 682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               246 non-null    object
#  1   text             246 non-null    object
#  2   human_or_ai      246 non-null    object
#  3   source_model     246 non-null    object
#  4   prompt           203 non-null    object
#  5   domain           246 non-null    object
#  6   language         246 non-null    object
#  7   edit_level       246 non-null    object
#  8   word_count       246 non-null    int64
#  9   generation_date  246 non-null    object
#  10  version          246 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 23.1+ KB

# %%
df.columns
# Out:
# Index(['id', 'text', 'human_or_ai', 'source_model', 'prompt', 'domain',
#        'language', 'edit_level', 'word_count', 'generation_date', 'version'],
#       dtype='object')

# %%
df.shape
# Out:
# (246, 11)
